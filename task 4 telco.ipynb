# %% [markdown]
# #### task 4.1
# f. engagement score to each user. Consider the engagement score as the Euclidean
# distance between the user data point & the less engaged cluster (use the first clustering
# for this) (Euclidean Distance)

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler
from scipy.spatial.distance import cdist

# Load the dataset
df = pd.read_csv('telcom_data1.csv')
df
# Out:
#            Bearer Id           Start  Start ms              End  End ms  \
# 0       1.310000e+19  04-04-19 12:01     770.0  4/25/2019 14:35   662.0
# 1       1.310000e+19  04-09-19 13:04     235.0   4/25/2019 8:15   606.0
# 2       1.310000e+19  04-09-19 17:42       1.0  4/25/2019 11:58   652.0
# 3       1.310000e+19   04-10-19 0:31     486.0   4/25/2019 7:36   171.0
# 4       1.310000e+19  04-12-19 20:10     565.0  4/25/2019 10:40   954.0
# ...              ...             ...       ...              ...     ...
# 149996  7.280000e+18  4/29/2019 7:28     451.0   4/30/2019 6:02   214.0
# 149997  7.350000e+18  4/29/2019 7:28     483.0  4/30/2019 10:41   187.0
# 149998  1.310000e+19  4/29/2019 7:28     283.0  4/30/2019 10:46   810.0
# 149999  1.310000e+19  4/29/2019 7:28     696.0  4/30/2019 10:40   327.0
# 150000           NaN             NaN       NaN              NaN     NaN
#
#         Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# 0       1823652.0  2.082010e+14   3.366496e+10  3.552120e+13
# 1       1365104.0  2.082020e+14   3.368185e+10  3.579400e+13
# 2       1361762.0  2.082000e+14   3.376063e+10  3.528150e+13
# 3       1321509.0  2.082010e+14   3.375034e+10  3.535660e+13
# 4       1089009.0  2.082010e+14   3.369980e+10  3.540700e+13
# ...           ...           ...            ...           ...
# 149996    81230.0  2.082020e+14   3.365069e+10  3.548310e+13
# 149997    97970.0  2.082020e+14   3.366345e+10  3.566050e+13
# 149998    98249.0  2.082020e+14   3.362189e+10  3.572120e+13
# 149999    97910.0  2.082020e+14   3.361962e+10  8.618620e+13
# 150000        NaN           NaN            NaN           NaN
#
#        Last Location Name  ...  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# 0                9.16E+15  ...          15854611.0          2501332.00
# 1                 L77566A  ...          20247395.0         19111729.00
# 2                 D42335A  ...          19725661.0         14699576.00
# 3                 T21824A  ...          21388122.0         15146643.00
# 4                 D88865A  ...          15259380.0         18962873.00
# ...                   ...  ...                 ...                 ...
# 149996            D20434A  ...          16191667.0         11763428.00
# 149997            D10223C  ...          13877234.0          8288284.00
# 149998            T51102A  ...          22660510.0          1855903.00
# 149999            L88342B  ...           8817106.0          8305402.00
# 150000                NaN  ...          11634072.5         11009410.13
#
#         Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# 0               8198936.00          9656251.00        278082303.0
# 1              18338413.00         17227132.00        608750074.0
# 2              17587794.00          6163408.00        229584621.0
# 3              13994646.00          1097942.00        799538153.0
# 4              17124581.00           415218.00        527707248.0
# ...                    ...                 ...                ...
# 149996         17883703.00         19678161.00        526609673.0
# 149997         19350146.00         21293148.00        626893062.0
# 149998          9963942.00          5065760.00        553539484.0
# 149999          3322253.00         13172589.00        352536971.0
# 150000         11626851.72         11001754.82        422044702.6
#
#         Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)  \
# 0            1.434415e+07       171744450.0      8.814393e+06
# 1            1.170709e+06       526904238.0      1.505514e+07
# 2            3.956300e+05       410692588.0      4.215763e+06
# 3            1.084972e+07       749039933.0      1.279728e+07
# 4            3.529801e+06       550709500.0      1.391032e+07
# ...                   ...               ...               ...
# 149996       9.197207e+06         3264510.0      1.348742e+07
# 149997       4.735033e+06       712180387.0      2.457758e+06
# 149998       1.339432e+07       121100856.0      1.131473e+07
# 149999       2.529475e+06       814713113.0      1.406930e+06
# 150000       8.288398e+06       421100544.2      8.264799e+06
#
#         Total UL (Bytes)  Total DL (Bytes)
# 0             36749741.0       308879636.0
# 1             53800391.0       653384965.0
# 2             27883638.0       279807335.0
# 3             43324218.0       846028530.0
# 4             38542814.0       569138589.0
# ...                  ...               ...
# 149996        57628851.0       574175259.0
# 149997        39135081.0       666648844.0
# 149998        34912224.0       592786405.0
# 149999        29626096.0       371895920.0
# 150000               NaN               NaN
#
# [150001 rows x 55 columns]

# %%
#Calculate the engagement metrics
df['sessions_frequency'] = df.groupby('MSISDN/Number')['Dur. (ms)'].transform('count')
df['duration_of_session'] = df['Dur. (ms)']
df['session_total_traffic'] = df['Total UL (Bytes)'] + df['Total DL (Bytes)']
df
# Out:
#            Bearer Id           Start  Start ms              End  End ms  \
# 0       1.310000e+19  04-04-19 12:01     770.0  4/25/2019 14:35   662.0
# 1       1.310000e+19  04-09-19 13:04     235.0   4/25/2019 8:15   606.0
# 2       1.310000e+19  04-09-19 17:42       1.0  4/25/2019 11:58   652.0
# 3       1.310000e+19   04-10-19 0:31     486.0   4/25/2019 7:36   171.0
# 4       1.310000e+19  04-12-19 20:10     565.0  4/25/2019 10:40   954.0
# ...              ...             ...       ...              ...     ...
# 149996  7.280000e+18  4/29/2019 7:28     451.0   4/30/2019 6:02   214.0
# 149997  7.350000e+18  4/29/2019 7:28     483.0  4/30/2019 10:41   187.0
# 149998  1.310000e+19  4/29/2019 7:28     283.0  4/30/2019 10:46   810.0
# 149999  1.310000e+19  4/29/2019 7:28     696.0  4/30/2019 10:40   327.0
# 150000           NaN             NaN       NaN              NaN     NaN
#
#         Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# 0       1823652.0  2.082010e+14   3.366496e+10  3.552120e+13
# 1       1365104.0  2.082020e+14   3.368185e+10  3.579400e+13
# 2       1361762.0  2.082000e+14   3.376063e+10  3.528150e+13
# 3       1321509.0  2.082010e+14   3.375034e+10  3.535660e+13
# 4       1089009.0  2.082010e+14   3.369980e+10  3.540700e+13
# ...           ...           ...            ...           ...
# 149996    81230.0  2.082020e+14   3.365069e+10  3.548310e+13
# 149997    97970.0  2.082020e+14   3.366345e+10  3.566050e+13
# 149998    98249.0  2.082020e+14   3.362189e+10  3.572120e+13
# 149999    97910.0  2.082020e+14   3.361962e+10  8.618620e+13
# 150000        NaN           NaN            NaN           NaN
#
#        Last Location Name  ...  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# 0                9.16E+15  ...          9656251.00        278082303.0
# 1                 L77566A  ...         17227132.00        608750074.0
# 2                 D42335A  ...          6163408.00        229584621.0
# 3                 T21824A  ...          1097942.00        799538153.0
# 4                 D88865A  ...           415218.00        527707248.0
# ...                   ...  ...                 ...                ...
# 149996            D20434A  ...         19678161.00        526609673.0
# 149997            D10223C  ...         21293148.00        626893062.0
# 149998            T51102A  ...          5065760.00        553539484.0
# 149999            L88342B  ...         13172589.00        352536971.0
# 150000                NaN  ...         11001754.82        422044702.6
#
#         Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)  \
# 0            1.434415e+07       171744450.0      8.814393e+06
# 1            1.170709e+06       526904238.0      1.505514e+07
# 2            3.956300e+05       410692588.0      4.215763e+06
# 3            1.084972e+07       749039933.0      1.279728e+07
# 4            3.529801e+06       550709500.0      1.391032e+07
# ...                   ...               ...               ...
# 149996       9.197207e+06         3264510.0      1.348742e+07
# 149997       4.735033e+06       712180387.0      2.457758e+06
# 149998       1.339432e+07       121100856.0      1.131473e+07
# 149999       2.529475e+06       814713113.0      1.406930e+06
# 150000       8.288398e+06       421100544.2      8.264799e+06
#
#         Total UL (Bytes)  Total DL (Bytes)  sessions_frequency  \
# 0             36749741.0       308879636.0                 2.0
# 1             53800391.0       653384965.0                 2.0
# 2             27883638.0       279807335.0                 1.0
# 3             43324218.0       846028530.0                 1.0
# 4             38542814.0       569138589.0                 1.0
# ...                  ...               ...                 ...
# 149996        57628851.0       574175259.0                 1.0
# 149997        39135081.0       666648844.0                 2.0
# 149998        34912224.0       592786405.0                 1.0
# 149999        29626096.0       371895920.0                 1.0
# 150000               NaN               NaN                 NaN
#
#         duration_of_session  session_total_traffic
# 0                 1823652.0            345629377.0
# 1                 1365104.0            707185356.0
# 2                 1361762.0            307690973.0
# 3                 1321509.0            889352748.0
# 4                 1089009.0            607681403.0
# ...                     ...                    ...
# 149996              81230.0            631804110.0
# 149997              97970.0            705783925.0
# 149998              98249.0            627698629.0
# 149999              97910.0            401522016.0
# 150000                  NaN                    NaN
#
# [150001 rows x 58 columns]

# %%
# Aggregate the engagement metrics per customer id (MSISDN)
engagement_metrics = df.groupby('MSISDN/Number').agg({'Bearer Id': 'count', 'Dur. (ms)': 'sum', 'session_total_traffic': 'sum'})
engagement_metrics.columns = ['Sessions Frequency', 'Session Duration', 'Session Total Traffic']
engagement_metrics
# Out:
#                Sessions Frequency  Session Duration  Session Total Traffic
# MSISDN/Number
# 3.360100e+10                    1          116720.0           8.786906e+08
# 3.360100e+10                    1          181230.0           1.568596e+08
# 3.360100e+10                    1          134969.0           5.959665e+08
# 3.360101e+10                    1           49878.0           4.223207e+08
# 3.360101e+10                    2           37104.0           1.457411e+09
# ...                           ...               ...                    ...
# 3.379000e+10                    1            8810.0           7.146416e+08
# 3.379000e+10                    1          140988.0           4.803073e+08
# 3.197020e+12                    1          877385.0           2.321240e+08
# 3.370000e+14                    1          253030.0           5.962878e+08
# 8.823970e+14                    1          869844.0           1.391536e+08
#
# [106856 rows x 3 columns]

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler
mms = MinMaxScaler() # Normalization
ss = StandardScaler() # Standardization
from sklearn.cluster import KMeans
kmeans=KMeans()

# %%
engagement_metrics['Sessions Frequency']=mms.fit_transform(engagement_metrics[['Sessions Frequency']])
engagement_metrics['Session Duration']=mms.fit_transform(engagement_metrics[['Session Duration']])
engagement_metrics['Session Total Traffic']=mms.fit_transform(engagement_metrics[['Session Total Traffic']])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from scipy.spatial.distance import cdist

# %%
sse = {};
kmax = 10
fig = plt.subplots(figsize = (20,5))
# Elbow Method :
for k in range(1, 10):
    kmeans = KMeans(n_clusters=k, max_iter=1000).fit(engagement_metrics)
    sse[k] = kmeans.inertia_ # Inertia: Sum of distances of samples to their closest cluster center
sns.lineplot(x = list(sse.keys()), y = list(sse.values()));
plt.title('Elbow Method')
plt.xlabel("k : Number of cluster")
plt.ylabel("Sum of Squared Error")
plt.grid()

# %%
df1=engagement_metrics[['Sessions Frequency','Session Duration','Session Total Traffic']].values

# %%
# Run a k-means (k=2) to classify customers into two groups of engagement
kmeans = KMeans(n_clusters=2,max_iter=1000)
kmeans.fit(df1)
# Out:
# KMeans(max_iter=1000, n_clusters=2)

# %%
cluster = kmeans.cluster_centers_

# %%
cluster
# Out:
# array([[0.06175697, 0.00571687, 0.05514413],
#        [0.14895296, 0.01575592, 0.16509764]])

# %%
labels=kmeans.labels_

# %%
centroids=np.array(cluster)

# %%
cluster_labels = kmeans.labels_

# %%
cluster_centers=np.array(cluster)
cluster_centers
# Out:
# array([[0.06175697, 0.00571687, 0.05514413],
#        [0.14895296, 0.01575592, 0.16509764]])

# %%
from sklearn.metrics.pairwise import euclidean_distances
distances=euclidean_distances(df1,centroids)

# %%
less_engaged_cluster_index =0

# %%
engagement_score = distances[:,less_engaged_cluster_index]
engagement_score =mms.fit_transform(engagement_score.reshape(-1,1))

# %%
engagement_score
# Out:
# array([[0.02187568],
#        [0.02218038],
#        [0.0028406 ],
#        ...,
#        [0.02913726],
#        [0.00430842],
#        [0.03337929]])

# %%
engagement_metrics['engagement_score']=engagement_score
engagement_metrics
# Out:
#                Sessions Frequency  Session Duration  Session Total Traffic  \
# MSISDN/Number
# 3.360100e+10             0.055556          0.005908               0.095931
# 3.360100e+10             0.055556          0.009387               0.014026
# 3.360100e+10             0.055556          0.006892               0.063851
# 3.360101e+10             0.055556          0.002304               0.044148
# 3.360101e+10             0.111111          0.001615               0.161598
# ...                           ...               ...                    ...
# 3.379000e+10             0.055556          0.000090               0.077317
# 3.379000e+10             0.055556          0.007217               0.050727
# 3.197020e+12             0.055556          0.046922               0.022566
# 3.370000e+14             0.055556          0.013258               0.063887
# 8.823970e+14             0.055556          0.046515               0.012017
#
#                engagement_score
# MSISDN/Number
# 3.360100e+10           0.021876
# 3.360100e+10           0.022180
# 3.360100e+10           0.002841
# 3.360101e+10           0.004291
# 3.360101e+10           0.069399
# ...                         ...
# 3.379000e+10           0.010920
# 3.379000e+10           0.000972
# 3.197020e+12           0.029137
# 3.370000e+14           0.004308
# 8.823970e+14           0.033379
#
# [106856 rows x 4 columns]

# %% [markdown]
# g. experience score for each user. Consider the experience score as the Euclidean distance
# between the user data point & the worst experience cluster.

# %%
# User Experience Analysis
# Compute the average TCP retransmission, average RTT, handset type, and average throughput per customer
df['TCP Retransmission'] = df['TCP DL Retrans. Vol (Bytes)'] + df['TCP UL Retrans. Vol (Bytes)']
tcp_retransmission = df.groupby('MSISDN/Number')['TCP Retransmission'].mean()

df['RTT'] = (df['Avg RTT DL (ms)'] + df['Avg RTT UL (ms)']) / 2
rtt = df.groupby('MSISDN/Number')['RTT'].mean()

handset_type = df.groupby('MSISDN/Number')['Handset Type'].agg(lambda x: x.mode())
# Calculate the average throughput
df['avg_throughput'] = (df['Avg Bearer TP DL (kbps)'] + df['Avg Bearer TP UL (kbps)']) / 2
df['avg_throughput']
throughput = df.groupby('MSISDN/Number')['avg_throughput'].mean()

experience_metrics = pd.concat([tcp_retransmission, rtt, throughput], axis=1)
experience_metrics.columns = ['TCP Retransmission', 'RTT', 'Throughput']
experience_metrics
# Out:
#                TCP Retransmission    RTT  Throughput
# MSISDN/Number
# 3.360100e+10                  NaN  23.00        38.0
# 3.360100e+10                  NaN  15.50        49.5
# 3.360100e+10                  NaN    NaN        48.5
# 3.360101e+10                  NaN  42.00       124.0
# 3.360101e+10            9370832.0  29.75     14211.0
# ...                           ...    ...         ...
# 3.379000e+10             218045.0  26.00      5182.5
# 3.379000e+10                  NaN  20.00        58.0
# 3.197020e+12                  NaN    NaN         0.5
# 3.370000e+14                  NaN    NaN        16.5
# 8.823970e+14                  NaN    NaN         1.0
#
# [106856 rows x 3 columns]

# %%
# Check for missing values
print(experience_metrics.isnull().sum())
# Out:
# TCP Retransmission    67565
# RTT                   18544
# Throughput                0
# dtype: int64

# %%
# Fill missing values with the mean of the column
experience_metrics.fillna(experience_metrics.mean(), inplace=True)

# %%
from sklearn.preprocessing import MinMaxScaler

# Create a MinMaxScaler object
mms = MinMaxScaler()

# Scale the 'TCP Retransmission', 'RTT', and 'Throughput' columns
experience_metrics[['TCP Retransmission', 'RTT', 'Throughput']] = mms.fit_transform(experience_metrics[['TCP Retransmission', 'RTT', 'Throughput']])
experience_metrics
# Out:
#                TCP Retransmission       RTT  Throughput
# MSISDN/Number
# 3.360100e+10             0.004919  0.000475    0.000268
# 3.360100e+10             0.004919  0.000320    0.000349
# 3.360100e+10             0.004919  0.001396    0.000342
# 3.360101e+10             0.004919  0.000867    0.000873
# 3.360101e+10             0.002178  0.000614    0.100102
# ...                           ...       ...         ...
# 3.379000e+10             0.000051  0.000537    0.036505
# 3.379000e+10             0.004919  0.000413    0.000409
# 3.197020e+12             0.004919  0.001396    0.000004
# 3.370000e+14             0.004919  0.001396    0.000116
# 8.823970e+14             0.004919  0.001396    0.000007
#
# [106856 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sse = {};
kmax = 10
fig = plt.subplots(figsize = (20,5))
# Elbow Method :
for k in range(1, 10):
    kmeans = KMeans(n_clusters=k, max_iter=1000).fit(experience_metrics)
    sse[k] = kmeans.inertia_ # Inertia: Sum of distances of samples to their closest cluster center
sns.lineplot(x = list(sse.keys()), y = list(sse.values()));
plt.title('Elbow Method')
plt.xlabel("k : Number of cluster")
plt.ylabel("Sum of Squared Error")
plt.grid()

# %%
from sklearn.cluster import KMeans
kmeans=KMeans()

# %%
# Run a k-means (k=2) to classify customers into two groups of engagement
kmeans = KMeans(n_clusters=2)
kmeans.fit(experience_metrics)
experience_metrics['Cluster'] = kmeans.labels_
experience_metrics['Cluster']
# Out:
# MSISDN/Number
# 3.360100e+10    1
# 3.360100e+10    1
# 3.360100e+10    1
# 3.360101e+10    1
# 3.360101e+10    1
#                ..
# 3.379000e+10    1
# 3.379000e+10    1
# 3.197020e+12    1
# 3.370000e+14    1
# 8.823970e+14    1
# Name: Cluster, Length: 106856, dtype: int32

# %%
# Assign an experience score for each user. Consider the experience score as the Euclidean distance between the user data point & the worst experience cluster.
worst_experience_cluster_center = kmeans.cluster_centers_[np.argmax(kmeans.cluster_centers_[:, 1])]
experience_score = cdist(experience_metrics, [worst_experience_cluster_center], metric='euclidean').flatten() 
experience_score
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [29], in <cell line: 3>()
#       1 # Assign an experience score for each user. Consider the experience score as the Euclidean distance between the user data point & the worst experience cluster.
#       2 worst_experience_cluster_center = kmeans.cluster_centers_[np.argmax(kmeans.cluster_centers_[:, 0])]
# ----> 3 experience_score = cdist(experience_metrics, [worst_experience_cluster_center], metric='euclidean').flatten()
#       4 experience_score
#
# File ~\anaconda3\lib\site-packages\scipy\spatial\distance.py:2935, in cdist(XA, XB, metric, out, **kwargs)
#    2933     raise ValueError('XB must be a 2-dimensional array.')
#    2934 if s[1] != sB[1]:
# -> 2935     raise ValueError('XA and XB must have the same number of columns '
#    2936                      '(i.e. feature dimension.)')
#    2938 mA = s[0]
#    2939 mB = sB[0]
#
# ValueError: XA and XB must have the same number of columns (i.e. feature dimension.)

# %%
experience_metrics['experience_score']=experience_score
experience_metrics

# %%
df=pd.DataFrame({'MSISDN/NUMBER':engagement_metrics.index,
                 'engagement_score':engagement_metrics['engagement_score'],
                'experience_score':experience_metrics['experience_score']})
df=df.reset_index(drop=True)

# %%
df

# %% [markdown]
# #### task 4.2
# Consider the average of both engagement & experience scores as the satisfaction
# score & report the top 10 satisfied customer

# %%
# Consider the average of both engagement & experience scores as the satisfaction score & report the top 10 satisfied customer
df['satisfaction_score'] =df['engagement_score'] + df['experience_score'] / 2

satisfaction_score

# %%
df

# %%
top_10_satisfied_customers = df.sort_values(by='satisfaction_score',ascending=False).head(10)

# %%
top_10_satisfied_customers

# %% [markdown]
# #### task 4.3
# Build a regression model of your choice to predict the satisfaction score of a customer

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
x = df(['engagement_score'], ['experience_score'])
y = satisfaction_score
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 x = df(['engagement_score'], ['experience_score'])
#       2 y = satisfaction_score
#
# NameError: name 'df' is not defined

# %%
from sklearn.model_selection import train_test_split

# %%
# split the data into train and test data
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=40)

# %%
model = LinearRegression()
model.fit(X, y)

# %%
y_pred=model.predict(x_test)
y_pred

# %%
y_test

# %%
mse=mean_squared_error(y_test,y_pred)
mse

# %%
from sklearn.metrics import mean-absolute_error
 mean-absolute_error=(y_test,y_pred)

# %%
from sklearn.metrics import r2_score
r2=r2_score(y_test,y_pred)

# %% [markdown]
# # task 4.4
# Run a k-means (k=2) on the engagement & the experience score.

# %%
from sklearn.cluster import kMeans

# %%
data=df(['engagement_score'], ['experience_score'])
X= data.values

# %%
# run k=2
kmeans = KMeans(n_clusters=2,random_state=42)
kmeans.fit(X)

# %%
set the cluster
cluster_labels=kmeans.labels_

# %%
# plot the cluster
plt.scatter(X[:,0],X[:,1])
plt.xlabel('engagement_score')
plt.ylabel('experience_score')
plt.title('clustering on Engagement and Experiement scores')
plt.show()

# %% [markdown]
# #### task 4.5
# ##### aggregate avg satisfaction and experience score per cluster

# %%
cluster_data =pd.DataFrame({cluster;cluster_labels,'satisfaction score':df['satisfaction score']})

# %%
# calculate the avg satisfaction and experience score per cluster
agg_cluster=cluster_data.groupby('cluster').mean()

# %%
agg_cluster

# %%
agg_cluster.columns

# %%
#define the cluster and average scores

# %%
df
